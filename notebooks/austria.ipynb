# %%
import numpy as np
import pandas as pd

import tqdm

from matplotlib import pyplot as plt
from matplotlib import rcParams

import seaborn as sns
import datetime

import os

import process_times

# %%
CIRCUIT_NAME = "austria"
CIRCUIT_COUNTRY = "austria"
CIRCUIT_CITY = "spielberg"
GP_WEEKS = [26]
FIGURES_PATH = os.path.join("..", "figures", CIRCUIT_NAME)
TEAM_COLORS = {
    "Mercedes":"#00D2BE",
    "Custom":(22.6/255.0, 21.1/255.0, 29.0/255.0),
    "Mc Laren":"#FF8700",
    "Ferrari":"#DC0000",
    "Red Bull":"#0600EF",
    "Alpine":"#0090FF",
    "Aston Martin":"#006F62",
    "Haas":"#8c8c8c",
    "Williams":"#005AFF",
    "Alfa Romeo":"#900000",
    "AlphaTauri":"#2B4562",
}

# %%
if not os.path.exists(os.path.join("..", "figures")):
    os.mkdir(os.path.join("..", "figures"))
if not os.path.exists(FIGURES_PATH):
    os.mkdir(FIGURES_PATH)

# %%
df = process_times.read_and_filter_csv(os.path.join("..", "data", f"{CIRCUIT_NAME}.csv"))
df
# Out:
#         frame         name      time       date custom  tc  gear  brakes  \
# 0         128      FatNerd  1:02.540 2021-10-31    Yes   0     0       0
# 1         131   alansitoDD  1:02.600 2021-11-08     No   1     0       1
# 2         134  JarnoOpmeer  1:02.606 2021-09-22    Yes   0     0       0
# 3         138  EskilGudrud  1:02.632 2022-05-20    Yes   1     0       0
# 4         141       igor97  1:02.640 2022-03-19    Yes   0     0       0
# ...       ...          ...       ...        ...    ...  ..   ...     ...
# 44227  174787     RudyCosy  1:05.212 2021-09-19     No   1     0       1
# 44228  174794        Senex  1:05.212 2022-04-19     No   0     1       1
# 44229  174811          ben  1:05.212 2021-10-19    Yes   1     0       0
# 44230  174827  RotMariboro  1:05.212 2022-04-10    Yes   1     1       0
# 44231  174797      Spongey  1:05.212 2022-01-01    Yes   1     0       1
#
#            team  time_s
# 0      Mc Laren  62.540
# 1      Red Bull  62.600
# 2      Mercedes  62.606
# 3      Mercedes  62.632
# 4      Mc Laren  62.640
# ...         ...     ...
# 44227   Ferrari  65.212
# 44228  Mercedes  65.212
# 44229  Mercedes  65.212
# 44230   Ferrari  65.212
# 44231  Mercedes  65.212
#
# [44232 rows x 10 columns]

# %%
process_times.plot_time_dist(df, FIGURES_PATH)

# %%
process_times.plot_cum_time_dist(df, FIGURES_PATH)

# %%
process_times.plot_team_dist(df, FIGURES_PATH)

# %%
process_times.plot_assist_dist(df, FIGURES_PATH)

# %%
process_times.plot_weekday(df, CIRCUIT_NAME, GP_WEEKS, FIGURES_PATH)

# %%
process_times.plot_team_times(df, FIGURES_PATH)

# %%
process_times.generate_html(CIRCUIT_NAME, CIRCUIT_COUNTRY, CIRCUIT_CITY)
