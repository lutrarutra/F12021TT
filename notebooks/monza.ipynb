# %%
import numpy as np
import pandas as pd

import tqdm

from matplotlib import pyplot as plt
from matplotlib import rcParams

import seaborn as sns
import datetime

import os

import process_times

# %%
CIRCUIT_NAME = "monza"
CIRCUIT_COUNTRY = "italy"
CIRCUIT_CITY = "monza"
GP_WEEKS = [36]
FIGURES_PATH = os.path.join("..", "figures", CIRCUIT_NAME)
TEAM_COLORS = {
    "Mercedes":"#00D2BE",
    "Custom":(22.6/255.0, 21.1/255.0, 29.0/255.0),
    "Mc Laren":"#FF8700",
    "Ferrari":"#DC0000",
    "Red Bull":"#0600EF",
    "Alpine":"#0090FF",
    "Aston Martin":"#006F62",
    "Haas":"#8c8c8c",
    "Williams":"#005AFF",
    "Alfa Romeo":"#900000",
    "AlphaTauri":"#2B4562",
}

# %%
if not os.path.exists(os.path.join("..", "figures")):
    os.mkdir(os.path.join("..", "figures"))
if not os.path.exists(FIGURES_PATH):
    os.mkdir(FIGURES_PATH)

# %%
df = process_times.read_and_filter_csv(os.path.join("..", "data", f"{CIRCUIT_NAME}.csv"))
df
# Out:
#         frame           name      time       date custom  tc  gear  brakes  \
# 0         147  LucasBlakeley  1:18.564 2021-09-17    Yes   0     0       0
# 1         151           Tape  1:18.709 2022-05-12    Yes   0     0       0
# 2         154      CanAkinci  1:18.757 2021-09-18    Yes   0     0       0
# 3         157     DavidVince  1:18.787 2021-09-20    Yes   0     0       0
# 4         187         Evsten  1:18.804 2021-09-18    Yes   0     0       1
# ...       ...            ...       ...        ...    ...  ..   ...     ...
# 42456  169336    SaMueleteQl  1:22.362 2022-05-15    Yes   0     0       1
# 42457  169303           JULU  1:22.362 2021-12-13     No   1     0       1
# 42458  169310        cuchuRB  1:22.362 2021-12-13    Yes   1     1       1
# 42459  169340         JJoker  1:22.362 2021-12-01    Yes   0     0       1
# 42460  169366          biily  1:22.362 2022-01-01     No   1     1       1
#
#                team  time_s
# 0      Aston Martin  78.564
# 1          Red Bull  78.709
# 2            Alpine  78.757
# 3          Mercedes  78.787
# 4          Williams  78.804
# ...             ...     ...
# 42456       Ferrari  82.362
# 42457      Red Bull  82.362
# 42458      Red Bull  82.362
# 42459    AlphaTauri  82.362
# 42460      Red Bull  82.362
#
# [42461 rows x 10 columns]

# %%
process_times.plot_time_dist(df, FIGURES_PATH)

# %%
process_times.plot_cum_time_dist(df, FIGURES_PATH)

# %%
process_times.plot_team_dist(df, FIGURES_PATH)

# %%
process_times.plot_assist_dist(df, FIGURES_PATH)

# %%
process_times.plot_weekday(df, CIRCUIT_NAME, GP_WEEKS, FIGURES_PATH)

# %%
process_times.plot_team_times(df, FIGURES_PATH)

# %%
process_times.generate_html(CIRCUIT_NAME, CIRCUIT_COUNTRY, CIRCUIT_CITY)
